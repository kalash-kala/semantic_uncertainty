# %%
import pandas as pd

# %%
df_trained_generations = pd.read_json("/home/kalashkala/semantic_uncertainty/semantic_uncertainty/root/uncertainty/local_run/train_generations.jsonl", lines=True)
df_trained_generations
# Out:
#                      qw_14911--133/133_1320452.txt#0_1  \
# 0    {'question': 'The cocktail called a Tom Collin...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 145                                                NaN
# 146                                                NaN
# 147                                                NaN
# 148                                                NaN
# 149                                                NaN
#
#                         dpql_654--22/22_568872.txt#0_0  \
# 0                                                  NaN
# 1    {'question': 'The characters Denisov and Dolok...
# 2                                                  NaN
# 3                                                  NaN
# ...
